# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import  matplotlib.pyplot  as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"D:\5.7.2024 BR\Excel Report\Data project\evaluation/Rainfall.csv")

# %%
df
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0              W           44.0          W  ...        71.0         22.0
# 1            WNW           44.0        NNW  ...        44.0         25.0
# 2            WSW           46.0          W  ...        38.0         30.0
# 3             NE           24.0         SE  ...        45.0         16.0
# 4              W           41.0        ENE  ...        82.0         33.0
# ...          ...            ...        ...  ...         ...          ...
# 8420           E           31.0         SE  ...        51.0         24.0
# 8421         NNW           22.0         SE  ...        56.0         21.0
# 8422           N           37.0         SE  ...        53.0         24.0
# 8423          SE           28.0        SSE  ...        51.0         24.0
# 8424         NaN            NaN        ESE  ...        62.0         36.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0          1007.7       1007.1       8.0       NaN     16.9     21.8
# 1          1010.6       1007.8       NaN       NaN     17.2     24.3
# 2          1007.6       1008.7       NaN       2.0     21.0     23.2
# 3          1017.6       1012.8       NaN       NaN     18.1     26.5
# 4          1010.8       1006.0       7.0       8.0     17.8     29.7
# ...           ...          ...       ...       ...      ...      ...
# 8420       1024.6       1020.3       NaN       NaN     10.1     22.4
# 8421       1023.5       1019.1       NaN       NaN     10.9     24.5
# 8422       1021.0       1016.8       NaN       NaN     12.5     26.1
# 8423       1019.4       1016.5       3.0       2.0     15.1     26.0
# 8424       1020.2       1017.9       8.0       8.0     15.0     20.9
#
#       RainToday  RainTomorrow
# 0            No            No
# 1            No            No
# 2            No            No
# 3            No            No
# 4            No            No
# ...         ...           ...
# 8420         No            No
# 8421         No            No
# 8422         No            No
# 8423         No            No
# 8424         No           NaN
#
# [8425 rows x 23 columns]

# %%
df.shape
# Out:
# (8425, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
#  17  Cloud9am       6004 non-null   float64
#  18  Cloud3pm       5970 non-null   float64
#  19  Temp9am        8369 non-null   float64
#  20  Temp3pm        8329 non-null   float64
#  21  RainToday      8185 non-null   object
#  22  RainTomorrow   8186 non-null   object
# dtypes: float64(16), object(7)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
df.columns.tolist()
# Out:
# ['Date',
#  'Location',
#  'MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustDir',
#  'WindGustSpeed',
#  'WindDir9am',
#  'WindDir3pm',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
df['WindDir9am'].unique()
# Out:
# array(['W', 'NNW', 'SE', 'ENE', 'SW', 'SSE', 'S', 'NE', nan, 'SSW', 'N',
#        'WSW', 'ESE', 'E', 'NW', 'WNW', 'NNE'], dtype=object)

# %%
df['WindGustDir'].unique()
# Out:
# array(['W', 'WNW', 'WSW', 'NE', 'NNW', 'N', 'NNE', 'SW', nan, 'ENE',
#        'SSE', 'S', 'NW', 'SE', 'ESE', 'E', 'SSW'], dtype=object)

# %%
df['RainToday'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df['RainTomorrow'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df["MinTemp"]=df["MinTemp"].fillna(df["MinTemp"].mean())
df["MaxTemp"]=df["MaxTemp"].fillna(df["MaxTemp"].mean())
df["Rainfall"]=df["Rainfall"].fillna(df["Rainfall"].mean())
df["Evaporation"]=df["Evaporation"].fillna(df["Evaporation"].mean())
df["Sunshine"]=df["Sunshine"].fillna(df["Sunshine"].mean())
df["WindGustDir"]=df["WindGustDir"].fillna(df["WindGustDir"].mode()[0])
df["WindGustSpeed"]=df["WindGustSpeed"].fillna(df["WindGustSpeed"].mean())
df["WindDir9am"]=df["WindDir9am"].fillna(df["WindDir9am"].mode()[0])
df["WindDir3pm"]=df["WindDir3pm"].fillna(df["WindDir3pm"].mode()[0])
df["WindSpeed9am"]=df["WindSpeed9am"].fillna(df["WindSpeed9am"].mean())
df["WindSpeed3pm"]=df["WindSpeed3pm"].fillna(df["WindSpeed3pm"].mean())
df["Humidity9am"]=df["Humidity9am"].fillna(df["Humidity9am"].mean())
df["Humidity9am"]=df["Humidity9am"].fillna(df["Humidity9am"].mean())
df["Pressure9am"]=df["Pressure9am"].fillna(df["Pressure9am"].mean())
df["Pressure3pm"]=df["Pressure3pm"].fillna(df["Pressure3pm"].mean())
df["Cloud9am"]=df["Cloud9am"].fillna(df["Cloud9am"].mean())
df["Cloud3pm"]=df["Cloud3pm"].fillna(df["Cloud3pm"].mean())
df["Temp9am"]=df["Temp9am"].fillna(df["Temp9am"].mean())
df["Temp3pm"]=df["Temp3pm"].fillna(df["Temp3pm"].mean())
df["RainToday"]=df["RainToday"].fillna(df["RainToday"].mode()[0])
df["RainTomorrow"]=df["RainTomorrow"].fillna(df["RainTomorrow"].mode()[0])

# %%
df.isnull().sum()
# Out:
# Date               0
# Location           0
# MinTemp            0
# MaxTemp            0
# Rainfall           0
# Evaporation        0
# Sunshine           0
# WindGustDir        0
# WindGustSpeed      0
# WindDir9am         0
# WindDir3pm         0
# WindSpeed9am       0
# WindSpeed3pm       0
# Humidity9am        0
# Humidity3pm      102
# Pressure9am        0
# Pressure3pm        0
# Cloud9am           0
# Cloud3pm           0
# Temp9am            0
# Temp3pm            0
# RainToday          0
# RainTomorrow       0
# dtype: int64

# %%
df["Humidity3pm"]=df["Humidity3pm"].fillna(df["Humidity3pm"].mean())

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
df.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  8425.000000  8425.000000  8425.000000  8425.000000  8425.000000
# mean     13.193305    23.859976     2.805913     5.389395     7.632205
# std       5.379488     6.114516    10.309308     3.852004     2.825451
# min      -2.000000     8.200000     0.000000     0.000000     0.000000
# 25%       9.300000    19.300000     0.000000     4.000000     7.632205
# 50%      13.200000    23.300000     0.000000     5.389395     7.632205
# 75%      17.300000    28.000000     1.400000     5.389395     8.900000
# max      28.500000    45.500000   371.000000   145.000000    13.900000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    8425.000000   8425.000000   8425.000000  8425.000000  8425.000000
# mean       40.174469     13.847646     18.533662    67.822496    51.249790
# std        13.776101     10.128579      9.704759    16.774231    18.311894
# min         7.000000      0.000000      0.000000    10.000000     6.000000
# 25%        31.000000      6.000000     11.000000    56.000000    39.000000
# 50%        40.174469     13.000000     19.000000    68.000000    51.000000
# 75%        48.000000     20.000000     24.000000    80.000000    63.000000
# max       107.000000     63.000000     83.000000   100.000000    99.000000
#
#        Pressure9am  Pressure3pm     Cloud9am     Cloud3pm      Temp9am  \
# count  8425.000000  8425.000000  8425.000000  8425.000000  8425.000000
# mean   1017.640233  1015.236075     4.566622     4.503183    17.762015
# std       6.275759     6.217451     2.429205     2.299419     5.608301
# min     989.800000   982.900000     0.000000     0.000000     1.900000
# 25%    1014.000000  1011.400000     3.000000     3.000000    13.800000
# 50%    1017.640233  1015.236075     4.566622     4.503183    17.762015
# 75%    1021.300000  1018.800000     7.000000     7.000000    21.900000
# max    1039.000000  1036.000000     8.000000     8.000000    39.400000
#
#            Temp3pm
# count  8425.000000
# mean     22.442934
# std       5.945849
# min       7.300000
# 25%      18.100000
# 50%      22.000000
# 75%      26.300000
# max      44.100000

# %%
df.drop('Date',axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# object data type convert into numeric data type using lebel encoder 
encoder = LabelEncoder()
df['Location'] = encoder.fit_transform(df['Location'])
df['WindGustDir'] = encoder.fit_transform(df['WindGustDir'])

df['WindDir9am'] = encoder.fit_transform(df['WindDir9am'])
df['WindDir3pm'] = encoder.fit_transform(df['WindDir3pm'])

df['RainToday'] = encoder.fit_transform(df['RainToday'])
df['RainTomorrow'] = encoder.fit_transform(df['RainTomorrow'])

# %%
df.describe()
# Out:
#           Location      MinTemp      MaxTemp     Rainfall  Evaporation  \
# count  8425.000000  8425.000000  8425.000000  8425.000000  8425.000000
# mean      5.793591    13.193305    23.859976     2.805913     5.389395
# std       3.162654     5.379488     6.114516    10.309308     3.852004
# min       0.000000    -2.000000     8.200000     0.000000     0.000000
# 25%       3.000000     9.300000    19.300000     0.000000     4.000000
# 50%       6.000000    13.200000    23.300000     0.000000     5.389395
# 75%       8.000000    17.300000    28.000000     1.400000     5.389395
# max      11.000000    28.500000    45.500000   371.000000   145.000000
#
#           Sunshine  WindGustDir  WindGustSpeed   WindDir9am   WindDir3pm  ...  \
# count  8425.000000  8425.000000    8425.000000  8425.000000  8425.000000  ...
# mean      7.632205     7.217804      40.174469     7.267418     7.810445  ...
# std       2.825451     4.702616      13.776101     4.588045     4.430162  ...
# min       0.000000     0.000000       7.000000     0.000000     0.000000  ...
# 25%       7.632205     3.000000      31.000000     3.000000     4.000000  ...
# 50%       7.632205     7.000000      40.174469     7.000000     8.000000  ...
# 75%       8.900000    12.000000      48.000000    12.000000    11.000000  ...
# max      13.900000    15.000000     107.000000    15.000000    15.000000  ...
#
#        Humidity9am  Humidity3pm  Pressure9am  Pressure3pm     Cloud9am  \
# count  8425.000000  8425.000000  8425.000000  8425.000000  8425.000000
# mean     67.822496    51.249790  1017.640233  1015.236075     4.566622
# std      16.774231    18.311894     6.275759     6.217451     2.429205
# min      10.000000     6.000000   989.800000   982.900000     0.000000
# 25%      56.000000    39.000000  1014.000000  1011.400000     3.000000
# 50%      68.000000    51.000000  1017.640233  1015.236075     4.566622
# 75%      80.000000    63.000000  1021.300000  1018.800000     7.000000
# max     100.000000    99.000000  1039.000000  1036.000000     8.000000
#
#           Cloud3pm      Temp9am      Temp3pm    RainToday  RainTomorrow
# count  8425.000000  8425.000000  8425.000000  8425.000000   8425.000000
# mean      4.503183    17.762015    22.442934     0.236202      0.236320
# std       2.299419     5.608301     5.945849     0.424773      0.424846
# min       0.000000     1.900000     7.300000     0.000000      0.000000
# 25%       3.000000    13.800000    18.100000     0.000000      0.000000
# 50%       4.503183    17.762015    22.000000     0.000000      0.000000
# 75%       7.000000    21.900000    26.300000     0.000000      0.000000
# max       8.000000    39.400000    44.100000     1.000000      1.000000
#
# [8 rows x 22 columns]

# %%
# Plotting Heatmap (Correlation matrix)
df_corr = df.corr() 

plt.figure(figsize=(14,8))
sns.heatmap(df_corr, annot=True, annot_kws={'size':7})
plt.show()

# %%
# draw the box plot to check outliers

plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<=22:
        plt.subplot(6,4,p)
        sns.boxplot(df[i],palette="Set2_r")
        plt.xlabel(i)
    p+=1
plt.show()

# %%
# correlation between label and features using barplot
plt.figure(figsize=(22,7))
df.corr()['Rainfall'].sort_values(ascending=False).drop(['Rainfall']).plot(kind='bar', color="m")
plt.xlabel('Feature', fontsize = 15)
plt.ylabel('Target', fontsize = 15)
plt.title("Correlation between label and features using barplot", fontsize = 20)
plt.show()

# %% [markdown]
# # Separating features and label Separating features and label

# %%
x = df.drop("RainTomorrow",axis = 1)
y = df["RainTomorrow"]

# %%
# Import necessory libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score,classification_report
# %matplotlib inline
import scipy.stats as stats
from scipy.stats import zscore
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn import metrics

# %% [markdown]
# # Feature scaling using standard Scalarization

# %%
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#       Location   MinTemp       MaxTemp  Rainfall   Evaporation      Sunshine  \
# 0    -1.515776  0.038425 -1.570089e-01 -0.213986 -2.305893e-16  3.143679e-16
# 1    -1.515776 -1.076989  2.028121e-01 -0.272189 -2.305893e-16  3.143679e-16
# 2    -1.515776 -0.054526  3.009450e-01 -0.272189 -2.305893e-16  3.143679e-16
# 3    -1.515776 -0.742365  6.771214e-01 -0.272189 -2.305893e-16  3.143679e-16
# 4    -1.515776  0.800625  1.380408e+00 -0.175183 -2.305893e-16  3.143679e-16
# ...        ...       ...           ...       ...           ...           ...
# 8420  1.013895 -1.932140 -7.523137e-02 -0.272189 -2.305893e-16  3.143679e-16
# 8421  1.013895 -1.783418  2.355231e-01 -0.272189 -2.305893e-16  3.143679e-16
# 8422  1.013895 -1.448794  4.972110e-01 -0.272189 -2.305893e-16  3.143679e-16
# 8423  1.013895 -1.002628  5.135665e-01 -0.272189 -2.305893e-16  3.143679e-16
# 8424  1.013895  0.317279  5.810639e-16 -0.272189 -2.305893e-16  3.143679e-16
#
#       WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  WindSpeed3pm  \
# 0        1.229643       0.277710    1.249535    1.397222  ...      0.563297
# 1        1.442303       0.277710   -0.276260    1.622961  ...      0.357200
# 2        1.654964       0.422897    1.249535    1.622961  ...      0.769394
# 3       -0.684299      -1.174166    0.377652   -1.763120  ...     -0.982428
# 4        1.229643       0.059928   -1.366114   -0.182949  ...      0.151104
# ...           ...            ...         ...         ...  ...           ...
# 8420    -1.534940      -0.666009    0.377652   -1.537381  ...     -0.776331
# 8421    -0.258979      -1.319354    0.377652   -1.085904  ...     -0.982428
# 8422    -0.896959      -0.230447    0.377652    1.397222  ...     -0.982428
# 8423     0.379002      -0.883791    0.595623   -1.085904  ...     -1.188525
# 8424    -0.896959       0.000000   -1.148143   -1.311643  ...     -0.158041
#
#       Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# 0        0.189439    -1.597406    -1.584003    -1.308665  1.413459
# 1       -1.420268    -1.433568    -1.121880    -1.196072  0.000000
# 2       -1.777981    -1.160505    -1.599939    -1.051309  0.000000
# 3       -1.360650    -1.925081    -0.006411    -0.391836  0.000000
# 4        0.845246    -0.996668    -1.090010    -1.485596  1.001777
# ...           ...          ...          ...          ...       ...
# 8420    -1.002937    -1.488181     1.109058     0.814518  0.000000
# 8421    -0.704843    -1.652018     0.933770     0.621501  0.000000
# 8422    -0.883699    -1.488181     0.535388     0.251553  0.000000
# 8423    -1.002937    -1.488181     0.280424     0.203299 -0.644950
# 8424    -0.347130    -0.832830     0.407906     0.428485  1.413459
#
#           Cloud3pm   Temp9am   Temp3pm  RainToday
# 0     3.862851e-16 -0.153712 -0.108138  -0.556099
# 1     3.862851e-16 -0.100217  0.312348  -0.556099
# 2    -1.088680e+00  0.577390  0.127334  -0.556099
# 3     3.862851e-16  0.060269  0.682376  -0.556099
# 4     1.520830e+00  0.006773  1.220599  -0.556099
# ...            ...       ...       ...        ...
# 8420  3.862851e-16 -1.366273 -0.007221  -0.556099
# 8421  3.862851e-16 -1.223619  0.345987  -0.556099
# 8422  3.862851e-16 -0.938310  0.615099  -0.556099
# 8423 -1.088680e+00 -0.474684  0.598279  -0.556099
# 8424  1.520830e+00 -0.492516 -0.259513  -0.556099
#
# [8425 rows x 21 columns]

# %% [markdown]
# # Creating the training and testing data sets

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.27, random_state=200)

print('Size of X_train : ', x_train.shape)
print('Size of y_train : ', y_train.shape)
print('Size of X_test : ', x_test.shape)
print('Size of Y_test : ', y_test.shape)
# Out:
# Size of X_train :  (6150, 21)
# Size of y_train :  (6150,)
# Size of X_test :  (2275, 21)
# Size of Y_test :  (2275,)

# %% [markdown]
# # Machine Learning Model for Regression and Evaluation Metrics

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, confusion_matrix
from sklearn.model_selection import cross_val_score, RandomizedSearchCV, GridSearchCV
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression


LR=LinearRegression()

for i in range(0,110):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    LR.fit(x_train,y_train)
    LR_predict_train=LR.predict(x_train)
    LR_predict_test=LR.predict(x_test)
    print(f'At random state {i}, The training accuracy is: {r2_score(y_train,LR_predict_train)}')
    print(f'At random state {i}, The test accuracy is: {r2_score(y_test,LR_predict_test)}')
    print('\n')
# Out:
# At random state 0, The training accuracy is: 0.3092781712530255
# At random state 0, The test accuracy is: 0.32221719650256164
#
#
# At random state 1, The training accuracy is: 0.3198070111908141
# At random state 1, The test accuracy is: 0.2759712674604762
#
#
# At random state 2, The training accuracy is: 0.3052398136395108
# At random state 2, The test accuracy is: 0.33800492769566015
#
#
# At random state 3, The training accuracy is: 0.31570896179188845
# At random state 3, The test accuracy is: 0.2966415535381024
#
#
# At random state 4, The training accuracy is: 0.31355554385652695
# At random state 4, The test accuracy is: 0.30571997861106437
#
#
# At random state 5, The training accuracy is: 0.3126639813654626
# At random state 5, The test accuracy is: 0.307522046936601
#
#
# At random state 6, The training accuracy is: 0.31311071322783957
# At random state 6, The test accuracy is: 0.306612441482324
#
#
# At random state 7, The training accuracy is: 0.3163428884134297
# At random state 7, The test accuracy is: 0.2949547506569581
#
#
# At random state 8, The training accuracy is: 0.31603413150672266
# At random state 8, The test accuracy is: 0.2957491528002074
#
#
# At random state 9, The training accuracy is: 0.3142257605655956
# At random state 9, The test accuracy is: 0.3025464135611122
#
#
# At random state 10, The training accuracy is: 0.31372907044639853
# At random state 10, The test accuracy is: 0.30442823385717643
#
#
# At random state 11, The training accuracy is: 0.30681423912230454
# At random state 11, The test accuracy is: 0.33153095792407605
#
#
# At random state 12, The training accuracy is: 0.3099721096565605
# At random state 12, The test accuracy is: 0.3194297071015654
#
#
# At random state 13, The training accuracy is: 0.319444507321488
# At random state 13, The test accuracy is: 0.2808531511259412
#
#
# At random state 14, The training accuracy is: 0.3090058167748472
# At random state 14, The test accuracy is: 0.32359339780545626
#
#
# At random state 15, The training accuracy is: 0.31270084023278
# At random state 15, The test accuracy is: 0.30930262920731844
#
#
# At random state 16, The training accuracy is: 0.31727727050055976
# At random state 16, The test accuracy is: 0.2902539912438675
#
#
# At random state 17, The training accuracy is: 0.31154389461553544
# At random state 17, The test accuracy is: 0.3130607690509838
#
#
# At random state 18, The training accuracy is: 0.3128522299665236
# At random state 18, The test accuracy is: 0.30827128301180007
#
#
# At random state 19, The training accuracy is: 0.30965815307238687
# At random state 19, The test accuracy is: 0.32008132076527473
#
#
# At random state 20, The training accuracy is: 0.305449507543599
# At random state 20, The test accuracy is: 0.3359541250361221
#
#
# At random state 21, The training accuracy is: 0.31946313717436536
# At random state 21, The test accuracy is: 0.28298373906409413
#
#
# At random state 22, The training accuracy is: 0.3108692761977704
# At random state 22, The test accuracy is: 0.3155462458769136
#
#
# At random state 23, The training accuracy is: 0.30464704810605836
# At random state 23, The test accuracy is: 0.34027068479670075
#
#
# At random state 24, The training accuracy is: 0.32085599200365567
# At random state 24, The test accuracy is: 0.27678473261683334
#
#
# At random state 25, The training accuracy is: 0.3170275961704663
# At random state 25, The test accuracy is: 0.29160046496677317
#
#
# At random state 26, The training accuracy is: 0.3149339053190042
# At random state 26, The test accuracy is: 0.30031504579929624
#
#
# At random state 27, The training accuracy is: 0.3132043909040336
# At random state 27, The test accuracy is: 0.306275518039
#
#
# At random state 28, The training accuracy is: 0.31429544742128057
# At random state 28, The test accuracy is: 0.30263603402221095
#
#
# At random state 29, The training accuracy is: 0.3085135543622698
# At random state 29, The test accuracy is: 0.32451501653897896
#
#
# At random state 30, The training accuracy is: 0.3167684913561041
# At random state 30, The test accuracy is: 0.29125291865459624
#
#
# At random state 31, The training accuracy is: 0.31506654749932417
# At random state 31, The test accuracy is: 0.2973220438280677
#
#
# At random state 32, The training accuracy is: 0.31250096852699505
# At random state 32, The test accuracy is: 0.30928787078206854
#
#
# At random state 33, The training accuracy is: 0.31796451902650824
# At random state 33, The test accuracy is: 0.28829510920888435
#
#
# At random state 34, The training accuracy is: 0.3125041325120482
# At random state 34, The test accuracy is: 0.30919739908074906
#
#
# At random state 35, The training accuracy is: 0.3163782018249621
# At random state 35, The test accuracy is: 0.29486265943541023
#
#
# At random state 36, The training accuracy is: 0.3072793804032484
# At random state 36, The test accuracy is: 0.3292160668134473
#
#
# At random state 37, The training accuracy is: 0.31292256515499484
# At random state 37, The test accuracy is: 0.30691559834479887
#
#
# At random state 38, The training accuracy is: 0.3091445895423004
# At random state 38, The test accuracy is: 0.3219912092469489
#
#
# At random state 39, The training accuracy is: 0.308854759240511
# At random state 39, The test accuracy is: 0.32039767365570426
#
#
# At random state 40, The training accuracy is: 0.3073285757712221
# At random state 40, The test accuracy is: 0.3281117566999323
#
#
# At random state 41, The training accuracy is: 0.30937513945314477
# At random state 41, The test accuracy is: 0.32176663809435
#
#
# At random state 42, The training accuracy is: 0.30723247025643163
# At random state 42, The test accuracy is: 0.33019325567618785
#
#
# At random state 43, The training accuracy is: 0.31039426685591753
# At random state 43, The test accuracy is: 0.3178287588191674
#
#
# At random state 44, The training accuracy is: 0.31609575836503123
# At random state 44, The test accuracy is: 0.29586304281279274
#
#
# At random state 45, The training accuracy is: 0.31375216285316354
# At random state 45, The test accuracy is: 0.30481844068086605
#
#
# At random state 46, The training accuracy is: 0.317669277976369
# At random state 46, The test accuracy is: 0.28616360310265454
#
#
# At random state 47, The training accuracy is: 0.31225405066617773
# At random state 47, The test accuracy is: 0.3082843108109816
#
#
# At random state 48, The training accuracy is: 0.3096958431212573
# At random state 48, The test accuracy is: 0.321916741193883
#
#
# At random state 49, The training accuracy is: 0.31979568811603387
# At random state 49, The test accuracy is: 0.27886400200517003
#
#
# At random state 50, The training accuracy is: 0.31480683173459567
# At random state 50, The test accuracy is: 0.2997304107089389
#
#
# At random state 51, The training accuracy is: 0.30764866986469663
# At random state 51, The test accuracy is: 0.3292486161043724
#
#
# At random state 52, The training accuracy is: 0.3098969630331536
# At random state 52, The test accuracy is: 0.3201233545904909
#
#
# At random state 53, The training accuracy is: 0.3138477130187941
# At random state 53, The test accuracy is: 0.30239702428170745
#
#
# At random state 54, The training accuracy is: 0.3166828208118728
# At random state 54, The test accuracy is: 0.29084916577383435
#
#
# At random state 55, The training accuracy is: 0.31126180662735925
# At random state 55, The test accuracy is: 0.31479868262913824
#
#
# At random state 56, The training accuracy is: 0.31745903451400814
# At random state 56, The test accuracy is: 0.28899152168092146
#
#
# At random state 57, The training accuracy is: 0.31039607692450044
# At random state 57, The test accuracy is: 0.3179376840345186
#
#
# At random state 58, The training accuracy is: 0.310709660332265
# At random state 58, The test accuracy is: 0.316760276574075
#
#
# At random state 59, The training accuracy is: 0.3197234524591429
# At random state 59, The test accuracy is: 0.2792994277679114
#
#
# At random state 60, The training accuracy is: 0.3180479453075732
# At random state 60, The test accuracy is: 0.2873342531512081
#
#
# At random state 61, The training accuracy is: 0.31241063638040967
# At random state 61, The test accuracy is: 0.3069075475989804
#
#
# At random state 62, The training accuracy is: 0.31791898797642104
# At random state 62, The test accuracy is: 0.2831773431863115
#
#
# At random state 63, The training accuracy is: 0.3108351830444377
# At random state 63, The test accuracy is: 0.31291788853272373
#
#
# At random state 64, The training accuracy is: 0.3147995471431021
# At random state 64, The test accuracy is: 0.30016211574824836
#
#
# At random state 65, The training accuracy is: 0.32280257906760956
# At random state 65, The test accuracy is: 0.26532446642365604
#
#
# At random state 66, The training accuracy is: 0.3142909866623217
# At random state 66, The test accuracy is: 0.3015405748537414
#
#
# At random state 67, The training accuracy is: 0.3130324789847576
# At random state 67, The test accuracy is: 0.30769123371929874
#
#
# At random state 68, The training accuracy is: 0.31222405143312604
# At random state 68, The test accuracy is: 0.30854643697819684
#
#
# At random state 69, The training accuracy is: 0.31164420398751647
# At random state 69, The test accuracy is: 0.31164850575319303
#
#
# At random state 70, The training accuracy is: 0.31261825475261207
# At random state 70, The test accuracy is: 0.3090726587320579
#
#
# At random state 71, The training accuracy is: 0.30917396982050405
# At random state 71, The test accuracy is: 0.32289272073795594
#
#
# At random state 72, The training accuracy is: 0.31058969350389154
# At random state 72, The test accuracy is: 0.3162514452886408
#
#
# At random state 73, The training accuracy is: 0.31230530256441813
# At random state 73, The test accuracy is: 0.3112130202033119
#
#
# At random state 74, The training accuracy is: 0.3094035359859293
# At random state 74, The test accuracy is: 0.3212904720687648
#
#
# At random state 75, The training accuracy is: 0.3234224468257295
# At random state 75, The test accuracy is: 0.2669325794165641
#
#
# At random state 76, The training accuracy is: 0.3143439566090773
# At random state 76, The test accuracy is: 0.3012736347685183
#
#
# At random state 77, The training accuracy is: 0.31514591762436805
# At random state 77, The test accuracy is: 0.29422978635428976
#
#
# At random state 78, The training accuracy is: 0.30770267591296285
# At random state 78, The test accuracy is: 0.32899180688218477
#
#
# At random state 79, The training accuracy is: 0.3186557690033309
# At random state 79, The test accuracy is: 0.2835151021026623
#
#
# At random state 80, The training accuracy is: 0.3165724108147493
# At random state 80, The test accuracy is: 0.29375579520030104
#
#
# At random state 81, The training accuracy is: 0.3057309837714013
# At random state 81, The test accuracy is: 0.33511688917667926
#
#
# At random state 82, The training accuracy is: 0.31194761124184955
# At random state 82, The test accuracy is: 0.310643418997107
#
#
# At random state 83, The training accuracy is: 0.31324434481661356
# At random state 83, The test accuracy is: 0.3067343068915187
#
#
# At random state 84, The training accuracy is: 0.3047402690218862
# At random state 84, The test accuracy is: 0.33602070633847947
#
#
# At random state 85, The training accuracy is: 0.3171630677648204
# At random state 85, The test accuracy is: 0.29103984143242034
#
#
# At random state 86, The training accuracy is: 0.32171889817356925
# At random state 86, The test accuracy is: 0.27020213918162306
#
#
# At random state 87, The training accuracy is: 0.3128072067402331
# At random state 87, The test accuracy is: 0.3077947772723092
#
#
# At random state 88, The training accuracy is: 0.3159907686290365
# At random state 88, The test accuracy is: 0.2940011292085598
#
#
# At random state 89, The training accuracy is: 0.30851058946443455
# At random state 89, The test accuracy is: 0.32353453507733754
#
#
# At random state 90, The training accuracy is: 0.3150710233755908
# At random state 90, The test accuracy is: 0.29535613482931067
#
#
# At random state 91, The training accuracy is: 0.30674396864586284
# At random state 91, The test accuracy is: 0.331142691897101
#
#
# At random state 92, The training accuracy is: 0.3147648634990263
# At random state 92, The test accuracy is: 0.2996530166576973
#
#
# At random state 93, The training accuracy is: 0.3098546647711299
# At random state 93, The test accuracy is: 0.31984800161386895
#
#
# At random state 94, The training accuracy is: 0.30758897202429036
# At random state 94, The test accuracy is: 0.3296052482445935
#
#
# At random state 95, The training accuracy is: 0.31717388678495795
# At random state 95, The test accuracy is: 0.28614023068017946
#
#
# At random state 96, The training accuracy is: 0.31864241074044397
# At random state 96, The test accuracy is: 0.2852883502795941
#
#
# At random state 97, The training accuracy is: 0.3163731242595721
# At random state 97, The test accuracy is: 0.29271557797145564
#
#
# At random state 98, The training accuracy is: 0.30774513079048615
# At random state 98, The test accuracy is: 0.3279467826258774
#
#
# At random state 99, The training accuracy is: 0.31059175109935233
# At random state 99, The test accuracy is: 0.3172671934979371
#
#
# At random state 100, The training accuracy is: 0.31264427987250887
# At random state 100, The test accuracy is: 0.3066155612640167
#
#
# At random state 101, The training accuracy is: 0.3040064861796461
# At random state 101, The test accuracy is: 0.34253385512215984
#
#
# At random state 102, The training accuracy is: 0.31304552157207866
# At random state 102, The test accuracy is: 0.3074003995174389
#
#
# At random state 103, The training accuracy is: 0.3169366028969517
# At random state 103, The test accuracy is: 0.29073443832528
#
#
# At random state 104, The training accuracy is: 0.315096346008796
# At random state 104, The test accuracy is: 0.2992773492947216
#
#
# At random state 105, The training accuracy is: 0.3141960071183596
# At random state 105, The test accuracy is: 0.3014931778355353
#
#
# At random state 106, The training accuracy is: 0.308358290032816
# At random state 106, The test accuracy is: 0.32421376083115205
#
#
# At random state 107, The training accuracy is: 0.31550550624135454
# At random state 107, The test accuracy is: 0.2956011027737192
#
#
# At random state 108, The training accuracy is: 0.31394081692275433
# At random state 108, The test accuracy is: 0.3020393652801602
#
#
# At random state 109, The training accuracy is: 0.31529063097591503
# At random state 109, The test accuracy is: 0.296689477808848

# %%
# Data split into train and test 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.27,random_state=100)

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
print(LR.score(x_train,y_train))
LR_predict=LR.predict(x_test)

print('MSE:',mean_squared_error(LR_predict,y_test))
print('MAE:',mean_absolute_error(LR_predict,y_test))
print('r2_score:',r2_score(LR_predict,y_test))
# Out:
# 0.3127588765014747
# MSE: 0.12002819088348465
# MAE: 0.26480932896750164
# r2_score: -1.0808992099890027

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge

R=Ridge()
R.fit(x_train,y_train)
print(R.score(x_train,y_train))
R_predict=R.predict(x_test)


print('MSE:',mean_squared_error(R_predict,y_test))
print('MAE:',mean_absolute_error(R_predict,y_test))
print('r2_score:',r2_score(R_predict,y_test))
# Out:
# 0.31275878216472797
# MSE: 0.12002912479884592
# MAE: 0.26481896788424936
# r2_score: -1.0816120240738285

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVR

svr=SVR(kernel='linear')
svr.fit(x_train,y_train)
print(svr.score(x_train,y_train))
svr_predict=svr.predict(x_test)

print('MSE:',mean_squared_error(svr_predict,y_test))
print('MAE:',mean_absolute_error(svr_predict,y_test))
print('r2_score:',r2_score(svr_predict,y_test))
# Out:
# 0.24258398145758486
# MSE: 0.13156469585794614
# MAE: 0.2437932978424208
# r2_score: -1.644675663719938

# %%
svr_p=SVR(kernel='poly')
svr_p.fit(x_train,y_train)
print(svr_p.score(x_train,y_train))
svrpred_p=svr_p.predict(x_test)

print('MSE:',mean_squared_error(svrpred_p,y_test))
print('MAE:',mean_absolute_error(svrpred_p,y_test))
print('r2_score:',r2_score(svrpred_p,y_test))
# Out:
# 0.45229036621656116
# MSE: 3.619750013740525
# MAE: 0.270708371798752
# r2_score: 0.006593490607200603

# %%
svr_r=SVR(kernel='rbf')
svr_r.fit(x_train,y_train)
print(svr_r.score(x_train,y_train))
svrpred_r=svr_r.predict(x_test)

print('MSE:',mean_squared_error(svrpred_r,y_test))
print('MAE:',mean_absolute_error(svrpred_r,y_test))
print('r2_score:',r2_score(svrpred_r,y_test))
# Out:
# 0.567951405486672
# MSE: 0.10744582028417606
# MAE: 0.20307376750528214
# r2_score: -0.1733773540813297

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

RF=RandomForestRegressor()
RF.fit(x_train,y_train)
print(RF.score(x_train,y_train))
RF_PRED=RF.predict(x_test)

print('MSE:',mean_squared_error(RF_PRED,y_test))
print('MAE:',mean_absolute_error(RF_PRED,y_test))
print('r2_score:',r2_score(RF_PRED,y_test))
# Out:
# 0.9327229286990941
# MSE: 0.08229485714285714
# MAE: 0.1843868131868132
# r2_score: -0.06340548499436816

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
print(DTR.score(x_train,y_train))
DTR_PRED=DTR.predict(x_test)

print('MSE:',mean_squared_error(DTR_PRED,y_test))
print('MAE:',mean_absolute_error(DTR_PRED,y_test))
print('r2_score:',r2_score(DTR_PRED,y_test))
# Out:
# 1.0
# MSE: 0.13802197802197802
# MAE: 0.13802197802197802
# r2_score: 0.20970764659157048

# %% [markdown]
# # Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
print(GBR.score(x_train,y_train))
GBR_PRED=GBR.predict(x_test)

print('MSE:',mean_squared_error(GBR_PRED,y_test))
print('MAE:',mean_absolute_error(GBR_PRED,y_test))
print('r2_score:',r2_score(GBR_PRED,y_test))
# Out:
# 0.4579906418587464
# MSE: 0.10800209558333645
# MAE: 0.22940100359235227
# r2_score: -0.6913083064471102

# %% [markdown]
# # Cross Validation score

# %%
from sklearn.model_selection import cross_val_score

np.random.seed(10)
def rmse_cv(model, x,y):
    rmse =- (cross_val_score(model, x,y, scoring='neg_mean_squared_error', cv=10))
    return(rmse)


models = [LinearRegression(),
             Ridge(),
             SVR(kernel='linear'),
             SVR(kernel='poly'),
             SVR(kernel='rbf'),
             RandomForestRegressor(),
             DecisionTreeRegressor(),  
             GradientBoostingRegressor(),]
            


names = ['LR','R','svr','svr_p','svr_r','RF','DTR','GBR']

for model,name in zip(models,names):
    score = rmse_cv(model,x,y)
    print("{}    : {:.6f}, {:4f}".format(name,score.mean(),score.std()))
# Out:
# LR    : 0.126925, 0.023587
# R    : 0.126923, 0.023582
# svr    : 0.139495, 0.023886
# svr_p    : 0.334282, 0.566177
# svr_r    : 0.110098, 0.024214
# RF    : 0.078224, 0.043414
# DTR    : 0.139209, 0.101554
# GBR    : 0.113300, 0.019570

# %% [markdown]
# Accourding to all metrics score selecting the Random forest Regressor for GridSeachCV

# %% [markdown]
# # Hyper Parameter Tuning

# %%
RFR = RandomForestRegressor()

param_grid = {  "n_estimators"      : [10,20,30],
                    "max_features"      : ["auto", "sqrt", "log2"],
                    "min_samples_split" : [2,4,8],
                    "bootstrap": [True, False],
                }

# %% [markdown]
# # Grid Search CV with random forest regressor

# %%
 grid = GridSearchCV(RFR, param_grid, n_jobs=-1, cv=5)

# %%
 grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [10, 20, 30]})

# %%
grid.best_params_
# Out:
# {'bootstrap': False,
#  'max_features': 'sqrt',
#  'min_samples_split': 2,
#  'n_estimators': 30}

# %%
final_RF=RandomForestRegressor(bootstrap = False, max_features = 'sqrt', min_samples_split = 2 , n_estimators = 30)
final_RF.fit(x_train,y_train)
print(final_RF.score(x_train,y_train))
RF_PRED=final_RF.predict(x_test)
# Out:
# 1.0

# %% [markdown]
# Choosing RandomForestRegressor as the best model

# %% [markdown]
# # Saving the Model

# %%
# Saving the model using .pkl

import joblib
joblib.dump(final_RF, "Rain_Tomorrow.pkl")
# Out:
# ['Rain_Tomorrow.pkl']

# %% [markdown]
# # Predicting the save model

# %%
# Let's load the saved model and get the prediction 

model = joblib.load("Rain_Tomorrow.pkl")

# Prediction 

prediction = model.predict(x_test)
prediction
# Out:
# array([0.        , 0.        , 0.8       , ..., 0.23333333, 0.        ,
#        0.1       ])

# %% [markdown]
# # Actual v/s prediction

# %%
a = np.array(y_test)
data = pd.DataFrame()
data["Predicted"]=prediction
data["Original"]=a
data
# Out:
#       Predicted  Original
# 0      0.000000         0
# 1      0.000000         0
# 2      0.800000         0
# 3      0.000000         0
# 4      0.000000         0
# ...         ...       ...
# 2270   0.933333         1
# 2271   0.133333         0
# 2272   0.233333         0
# 2273   0.000000         0
# 2274   0.100000         1
#
# [2275 rows x 2 columns]
